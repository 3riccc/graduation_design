# %%
# 文件操作
from operator import *
# 正则表达式
import re

# %%
# 打开文件
f = open('src/test1')

# %%
# 链接们
links = []

# %%
# 正则
linkPattern = re.compile(r'(href=".*?\")')

# %%
# 取到连接
for line in f.readlines():
    links = linkPattern.findall(line)

# 参数值们
paras = []
# 用正则从链接中匹配参数值
paraPattern = re.compile(r'(\=.*?&amp;)')



# 链接修剪并匹配
for link in links:
    # 修剪
    link = link[6:-1]
    # 匹配
    paraList = paraPattern.findall(link)
    for para in paraList:
        # 插入参数值数组
        paras.append(para[1:-5])
# 写入文件

for p in paras:
    print p
# Out:
# 593519963,3902313522
# 3877904193,3287017558
# 832538259,467263848
# 2510199064,2405297358
# 1500932085,745193163
# 3703781246,3349784983
# 3979684013,2630340395
# jQuery1111030891975587881926_1477276556615
# json
# index1
# list_index_top_tv_all
#
# 104
# exhao123-v
# exhao123-v
# index_top_tv_all
# game_kp
# navclient-auto-ffox
# 45.0.1
# 2.2
# json
# 12
# https%3A%2F%2Fgetfoxyproxy.org
# default807966
# 3.1.1
# sc-xO6cm22pcCVx9IMGMud0aT
# GB
#
#
#
# USD
# 3.1.1
# sc-xO6cm22pcCVx9IMGMud0aT
# json
# 12
# https%3A%2F%2Fgetfoxyproxy.org
# default153498
# 3.1.1
# sc-xO6cm22pcCVx9IMGMud0aT
# 96608247_hao_pg
# 1ug
# 113
# 1
# index
# 342708629825777189
# rpidmapping
# 2F78B5AAA0D73BEB29F6EE2ECD460F36
# undefined
# jQuery172023093211172717987_1477276535371
# default
# 1
# 7
# 512
# 512
# 1
# 3
# naked
#
#
# 28b0c86e_cpr
# 28b0c86e
# LP
#
# 2F78B5AAA0D73BEB29F6EE2ECD460F36
# hao123
#
# 1000300_1000200_1002000_1001900_1000700_1000900_1001300
# index
# 113
#
# 0
# 0
# 150-3-122-29
# 1
# ...

# %%
ma = re.findall(r'abc.*?\>','abc>   iii   abc>')
print ma
# Out:
# ['abc>', 'abc>']

# %%
str1 = 'http://jsonp.aid.alibaba.com/Umid/getDeviceInfo?_cbFunction=fn_7SkiPapG&amp;tokenid=gnARD4eyk4CAW8AAPzRVtVmmCqpjrpQn&amp;acookie=gnARD4e%2Byk4CAW8AAPzRV%2FtV&amp;n=first&amp;p1=b2d7334a3404b5af84ddd729bd46473775d33105621b4ffcc7ea3438dc82e3592803cb72bb3d2a4c4&amp;p2='
str2 = '"https://ynuf.alipay.com/service/um.json?xt=gnARD4eyk4CAW8AAPzRVtVmmCqpjrpQn&amp;xa=aliyun_aid&amp;xh=&amp;xs=55F3A8BFC9C50DDA45E81EBE27EA1C6B17D50B59DC479ECCB407AA8E42EBD3E8ED945FD950FD94644BB8ABA4A1C9B82E3B3AFC7891F17E86B0BD3B784D79EF617551097D4E8E0DF786675BF0A147228A560C44E5EADF9789DEC81F519AA12F8B278E213B3791E835&amp;x0=-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-&amp;x1=1%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5EMacIntel&amp;x2=Mozilla%5E%5E-%5E%5ENetscape%5E%5E5.0%20(Macintosh)%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5E-%5E%5EMozilla%2F5.0%20(Macintosh%3B%20Intel%20Mac%20OS%20X%2010.11%3B%20rv%3A45.0)%20Gecko%2F20100101%20Firefox%2F45.0%5E%5E-%5E%5E-&amp;x3=858%5E%5E1440%5E%5E-%5E%5E-%5E%5E900%5E%5Ezh-CN%5E%5Ehttp%253A%252F%252Fcdn.tanx.com%252Ft%252Facookie%252Facbeacon2.html%2523mm_26632322_6858406_35042231%5E%5EIntel%20Mac%20OS%20X%2010.11%5E%5E-%5E%5E-%5E%5E1477276539122%5E%5E480%5E%5E1440&amp;ext=%7Bepl%3A9%2Cep%3A%22ff243f2208ab99ef47761304757d4310dc6dacd3%22%2Cent%3A%22NC%22%2Ceca%3A%22gnARD4e%2Byk4CAW8AAPzRV%2FtV%22%2Cest%3A2%7D&amp;xv=2.1.4&amp;_callback=_3822_1477276539125'
str3 = 'http://log.mmstat.com/t.gif?cna=gnARD4e+yk4CAW8AAPzRV/tV&amp;cache=455&amp;cnaui=655089598'
# Out:
# gnARD4e+yk4CAW8AAPzRV/tV
# 455

# %%
http://jsonp.aid.alibaba.com/Umid/getDeviceInfo?_cbFunction=fn_sECCVybW&amp;tokenid=gnARD4eyk4CAW8AAPzRVtVmmCqpjrpQn&amp;acookie=gnARD4e%2Byk4CAW8AAPzRV%2FtV&amp;n=callback
